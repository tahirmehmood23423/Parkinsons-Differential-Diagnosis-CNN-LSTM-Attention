# %%
import os
import numpy as np
import pandas as pd

# %%
root_dir = "/kaggle/input/timeseries-dataset/Timeseries_dataset"

# Subfolders
timeseries_dir = f"{root_dir}/timeseries"
csv_dir = f"{root_dir}/csv_file"
root1_dir = "/kaggle/working"
preprocessed_dir = f"{root1_dir}/left_2s_10"
os.makedirs(preprocessed_dir, exist_ok=True)

# Output paths (saved into preprocessed folder)
out_x_path = f"{preprocessed_dir}/X_windows_right_2s_10_full_ds.npy"
out_d_path = f"{preprocessed_dir}/Y_disease_right_2s_10_labels.npy"
out_a_path = f"{preprocessed_dir}/Y_activity_right_2s_10_labels.npy"

# %%
print("Timeseries_dir:", timeseries_dir)
print("exists?", os.path.exists(timeseries_dir))
if os.path.exists(timeseries_dir):
    name=sorted(os.listdir(timeseries_dir))[:10]
    print("Samples files :", name)
print("\ncsv_dir:", csv_dir, "| Exists?", os.path.exists(csv_dir))
# Out:
# Timeseries_dir: /kaggle/input/timeseries-dataset/Timeseries_dataset/timeseries
# exists? True
# Samples files : ['001_CrossArms_LeftWrist.txt', '001_CrossArms_RightWrist.txt', '001_DrinkGlas_LeftWrist.txt', '001_DrinkGlas_RightWrist.txt', '001_Entrainment_LeftWrist.txt', '001_Entrainment_RightWrist.txt', '001_HoldWeight_LeftWrist.txt', '001_HoldWeight_RightWrist.txt', '001_LiftHold_LeftWrist.txt', '001_LiftHold_RightWrist.txt']
#
# csv_dir: /kaggle/input/timeseries-dataset/Timeseries_dataset/csv_file | Exists? True

# %%
df = pd.read_csv(f"{csv_dir}/file_list.csv")
df['id'] = df['id'].astype(int).astype(str).str.zfill(3)
df.head()
# Out:
#   resource_type   id study_id                 condition  \
# 0       patient  001     PADS                   Healthy
# 1       patient  002     PADS  Other Movement Disorders
# 2       patient  003     PADS                   Healthy
# 3       patient  004     PADS               Parkinson's
# 4       patient  005     PADS               Parkinson's
#
#                                      disease_comment  age_at_diagnosis  age  \
# 0                                                  -                56   56
# 1  Left-Sided resting tremor and hypokinesia with...                69   81
# 2                                                  -                45   45
# 3                            IPS akinetic-rigid type                63   67
# 4                            IPS tremordominant type                65   75
#
#    height  weight  gender handedness  appearance_in_kinship  \
# 0     173      78    male      right                   True
# 1     193     104    male      right                  False
# 2     170      78  female      right                  False
# 3     161      90  female      right                  False
# 4     172      86    male       left                  False
#
#   appearance_in_first_grade_kinship effect_of_alcohol_on_tremor  label
# 0                              True                     Unknown      0
# 1                               NaN                   No effect      2
# 2                               NaN                     Unknown      0
# 3                               NaN                   No effect      1
# 4                               NaN                     Unknown      1

# %%
from sklearn.preprocessing import LabelEncoder

# Map numeric labels back to names
label_names = {0: 'Healthy', 2: 'DD', 1: 'Parkinson'}
df['label_name'] = df['label'].map(label_names)

# 🔹 Explicit copy to avoid SettingWithCopyWarning
labeled_df = df[['id', 'label', 'label_name', 'gender']].copy()

# Encode gender (0=female, 1=male)
gender_encoder = LabelEncoder()
labeled_df['gender'] = gender_encoder.fit_transform(labeled_df['gender'])

print("Subjects:", len(labeled_df))
print(labeled_df.head())
# Out:
# Subjects: 469
#     id  label label_name  gender
# 0  001      0    Healthy       1
# 1  002      2         DD       1
# 2  003      0    Healthy       0
# 3  004      1  Parkinson       0
# 4  005      1  Parkinson       1

# %%
sampling_rate = 100
window_size_sec = 2

window_size = int(window_size_sec * sampling_rate)

stride_percent = 10
step_size = max(1, int(window_size * (stride_percent / 100)))

print("Window Size:", window_size)
print("Step Size:", step_size)
# Out:
# Window Size: 200
# Step Size: 20

# %%
def read_timeseries_txt(path):
    cols = ['Time', 'Acc_x','Acc_y','Acc_z','Gyro_x','Gyro_y','Gyro_z']
    df = pd.read_csv(path, sep=',', header=None, engine='python')
    if df.shape[1] != 7:
        raise ValueError(f"Unexpected column count in {path}: got {df.shape[1]}")
    df.columns = cols
    df_f = df.drop(columns=['Time']).astype('float32').values
    return df_f

# %%
files = os.listdir(timeseries_dir)
subjects_in_folder = sorted(list(set([f.split('_')[0] for f in files])))
print("Subjects found in timeseries folder:", len(subjects_in_folder))
print(subjects_in_folder[:50])   # print first 50
# Out:
# Subjects found in timeseries folder: 469
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050']

# %%
import os
import pandas as pd

# -----------------------------------------------------
# LOAD CSV METADATA
# -----------------------------------------------------
df = labeled_df.copy()

# Convert ID to 3-digit string to match filenames
df['id_str'] = df['id'].astype(str).str.zfill(3)

# -----------------------------------------------------
# EXTRACT SUBJECTS THAT HAVE COMPLETE DATA (20 FILES)
# -----------------------------------------------------
files = os.listdir(timeseries_dir)

# count how many files each subject has
file_counts = {}
for f in files:
    sid = f.split('_')[0]     # '001'
    file_counts[sid] = file_counts.get(sid, 0) + 1

# subjects with full 20 files
valid_subjects = [sid for sid, cnt in file_counts.items() if cnt == 20]

df_valid = df[df['id_str'].isin(valid_subjects)].copy()

print("Valid subjects with full data:", len(df_valid))
print(df_valid.head())

# -----------------------------------------------------
# SELECT 10 SUBJECTS PER CLASS WITH 5 MALE + 5 FEMALE
# -----------------------------------------------------
final_selection = []

for label_value, label_name in zip([0, 1, 2], ["Healthy", "Parkinson", "DD"]):
    
    df_class = df_valid[df_valid['label'] == label_value]
    
    males = df_class[df_class['gender'] == 1].head(3)
    females = df_class[df_class['gender'] == 0].head(3)
    
    if len(males) < 5 or len(females) < 5:
        print(f"⚠️ WARNING: Not enough subjects in {label_name} (Male/Female).")

    selected = pd.concat([males, females])
    final_selection.append(selected)

final_df = pd.concat(final_selection).reset_index(drop=True)

print("\n🎯 FINAL SELECTED SUBJECTS (30 TOTAL):")
print(final_df)

# -----------------------------------------------------
# SAVE FILE
# -----------------------------------------------------
final_df.to_csv("selected_LOSO_subjects.csv", index=False)
print("\nSaved: selected_LOSO_subjects.csv")
# Out:
# Valid subjects with full data: 469
#     id  label label_name  gender id_str
# 0  001      0    Healthy       1    001
# 1  002      2         DD       1    002
# 2  003      0    Healthy       0    003
# 3  004      1  Parkinson       0    004
# 4  005      1  Parkinson       1    005
# ⚠️ WARNING: Not enough subjects in Healthy (Male/Female).
# ⚠️ WARNING: Not enough subjects in Parkinson (Male/Female).
# ⚠️ WARNING: Not enough subjects in DD (Male/Female).
#
# 🎯 FINAL SELECTED SUBJECTS (30 TOTAL):
#      id  label label_name  gender id_str
# 0   001      0    Healthy       1    001
# 1   021      0    Healthy       1    021
# 2   046      0    Healthy       1    046
# 3   003      0    Healthy       0    003
# 4   027      0    Healthy       0    027
# 5   034      0    Healthy       0    034
# 6   005      1  Parkinson       1    005
# 7   009      1  Parkinson       1    009
# 8   010      1  Parkinson       1    010
# 9   004      1  Parkinson       0    004
# 10  006      1  Parkinson       0    006
# 11  008      1  Parkinson       0    008
# 12  002      2         DD       1    002
# 13  007      2         DD       1    007
# 14  011      2         DD       1    011
# 15  015      2         DD       0    015
# 16  018      2         DD       0    018
# 17  023      2         DD       0    023
#
# Saved: selected_LOSO_subjects.csv

# %%
def read_left_acc_txt(path):
    """
    Reads only left-hand accelerometer data (Acc_x, Acc_y, Acc_z)
    """
    cols = ['Time','Acc_x','Acc_y','Acc_z','Gyro_x','Gyro_y','Gyro_z']
    df = pd.read_csv(path, sep=',', header=None, engine='python')
    if df.shape[1] != 7:
        raise ValueError(f"Unexpected column count in {path}: got {df.shape[1]}")
    df.columns = cols
    
    # Only Acc_x, Acc_y, Acc_z
    df_acc = df[['Acc_x','Acc_y','Acc_z']].astype('float32').values
    return df_acc

def sliding_windows(data, window_size, step_size):
    windows = []
    for start in range(0, len(data) - window_size + 1, step_size):
        window = data[start:start + window_size]
        windows.append(window)
    return np.array(windows, dtype='float32')

# %%
X, y_activity, y_disease, y_subject = [], [], [], []

activity_map = {
    'CrossArms':0, 'DrinkGlas':1, 'Entrainment':2, 'HoldWeight':3,
    'LiftHold':4, 'PointFinger':5,
    'Relaxed':6, 'StretchHold':7, 'TouchIndex':8, 'TouchNose':9
}

for idx, row in final_df.iterrows():
    subject_id = row['id_str']
    disease_label = row['label']
    
    # Only left-hand files
    subject_files = [f for f in os.listdir(timeseries_dir) 
                     if f.startswith(subject_id) and "LeftWrist" in f]
    
    subject_data = []
    subject_labels = []
    
    # Concatenate all files for this subject
    for file in sorted(subject_files):
        activity_name = file.split('_')[1]
        data = read_left_acc_txt(os.path.join(timeseries_dir, file))
        
        subject_data.append(data)
        # Create a label array for early labeling
        labels = np.full((data.shape[0],), activity_map[activity_name])
        subject_labels.append(labels)
    
    # Concatenate all files
    subject_data = np.concatenate(subject_data, axis=0)
    subject_labels = np.concatenate(subject_labels, axis=0)
    
    # Apply sliding window
    for start in range(0, len(subject_data) - window_size + 1, step_size):
        window = subject_data[start:start + window_size]
        label = subject_labels[start]  # early labeling: first sample label
        
        X.append(window)
        y_activity.append(label)
        y_disease.append(disease_label)
        y_subject.append(int(subject_id))

# Convert to numpy arrays
X = np.array(X, dtype='float32')
y_activity = np.array(y_activity)
y_disease = np.array(y_disease)
y_subject = np.array(y_subject)

print("X shape (windows, timesteps, 3):", X.shape)
print("y_activity shape:", y_activity.shape)
print("y_disease shape:", y_disease.shape)
print("y_subject shape:", y_subject.shape)
# Out:
# X shape (windows, timesteps, 3): (10890, 200, 3)
# y_activity shape: (10890,)
# y_disease shape: (10890,)
# y_subject shape: (10890,)

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, LSTM, Dropout, Attention, Permute, Multiply, Lambda, Concatenate, GlobalAveragePooling1D, BatchNormalization
# Out:
# 2025-11-16 06:46:02.135104: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763275562.342317      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763275562.403321      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
unique, counts = np.unique(y_disease, return_counts=True)
disease_counts = dict(zip(unique, counts))

print("Samples per disease label:")
for d, c in disease_counts.items():
    print(f"Disease {d}: {c} samples")
# Out:
# Samples per disease label:
# Disease 0: 3630 samples
# Disease 1: 3630 samples
# Disease 2: 3630 samples

# %%
from sklearn.preprocessing import StandardScaler

# ---- Scaling the whole dataset ----
N, T, F = X.shape
print(f"Original shape: (N={N}, T={T}, F={F})")

# Flatten to (N*T, F) for scaling
X_2d = X.reshape(-1, F)

# Fit & transform with StandardScaler
scaler = StandardScaler()
X_scaled_2d = scaler.fit_transform(X_2d)

# Reshape back to (N, T, F)
X_scaled = X_scaled_2d.reshape(N, T, F)

print("✅ Scaling complete")
print("Scaled shape:", X_scaled.shape)

# Check mean & std of first feature
print("Feature[0] mean (should be ~0):", X_scaled[..., 0].mean())
print("Feature[0] std (should be ~1):", X_scaled[..., 0].std())

# Preview first sample (first 3 timesteps)
print("\nFirst sample (first 3 timesteps):")
print(X_scaled[0, :3, :])
# Out:
# Original shape: (N=10890, T=200, F=3)
# ✅ Scaling complete
# Scaled shape: (10890, 200, 3)
# Feature[0] mean (should be ~0): 2.466067e-09
# Feature[0] std (should be ~1): 1.0
#
# First sample (first 3 timesteps):
# [[-3.4770947e-02  4.0123925e-02 -4.1651172e-03]
#  [-4.1897960e-02  4.6013683e-02 -3.3560639e-06]
#  [-4.8908941e-02  6.3647494e-02 -1.7377853e-03]]

# %%
def loso_split(X, y_activity, y_subject, test_subject):
    train_idx = y_subject != test_subject
    test_idx = y_subject == test_subject
    
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y_activity[train_idx], y_activity[test_idx]
    
    return X_train, X_test, y_train, y_test

# %%
def build_self_attention_block(x, num_heads=4, key_dim=64, dropout_rate=0.15):
    x_norm = layers.LayerNormalization()(x)
    attn_out = layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x_norm, x_norm)
    x = layers.Add()([x, attn_out])  # residual
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    return x

# %%
def build_multi_task_model(timesteps=100, features=12,
                           num_disease=3, num_activities=10,
                           lstm_units=64, dense_units=64,
                           dropout_rate=0.15):
    input_layer = layers.Input(shape=(timesteps, features), name="inputs")

    # ---- CNN Block 1 ----
    x = layers.Conv1D(filters=64, kernel_size=7, padding="same",
                      activation="relu", kernel_regularizer=l2(1e-5))(input_layer)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)

    # ---- CNN Block 2 ----
    x = layers.Conv1D(filters=64, kernel_size=5, padding="same",
                      activation="relu", kernel_regularizer=l2(1e-5))(x)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)

    # ---- LSTM Layer (Unidirectional) ----
    x = layers.LSTM(lstm_units, return_sequences=True,
                    kernel_regularizer=l2(1e-5))(x)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)

    # ---- Self-Attention ----
    x = build_self_attention_block(x, num_heads=4, key_dim=lstm_units, dropout_rate=dropout_rate)

    # ---- Pool sequence to vector ----
    x = layers.GlobalAveragePooling1D()(x)

    # ---- Dense projection ----
    x = layers.Dense(dense_units, activation="relu", kernel_regularizer=l2(1e-5))(x)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)

    # ---- Outputs ----
    disease_output = layers.Dense(num_disease, activation="softmax", name="disease_output")(x)
    activity_output = layers.Dense(num_activities, activation="softmax", name="activity_output")(x)

    model = Model(inputs=input_layer, outputs=[disease_output, activity_output])
    return model

# %%
import tensorflow as tf
import os

def get_callbacks(checkpoint_dir, fold_no=None, save_every=10):
    """
    Returns Keras callbacks for model training:
    ✅ Saves model every `save_every` epochs.
    ✅ Saves the best model based on lowest val_loss.
    ✅ Compatible with Kaggle (temporary / working directory).
    """
    
    # --- Create a subfolder for this fold ---
    fold_dir = os.path.join(checkpoint_dir, f"fold_{fold_no}") if fold_no is not None else checkpoint_dir
    os.makedirs(fold_dir, exist_ok=True)

    # --- Custom callback to save every N epochs ---
    class SaveEveryNEpochs(tf.keras.callbacks.Callback):
        def __init__(self, save_freq, folder):
            super().__init__()
            self.save_freq = save_freq
            self.folder = folder

        def on_epoch_end(self, epoch, logs=None):
            logs = logs or {}
            if (epoch + 1) % self.save_freq == 0:
                val_loss = logs.get("val_loss", 0)
                filename = f"epoch_{epoch+1:03d}_valLoss_{val_loss:.4f}.keras"
                filepath = os.path.join(self.folder, filename)
                self.model.save(filepath)
                print(f"\n💾 Checkpoint saved at: {filepath}")

    # --- Callback to always save the best model based on val_loss ---
    best_model_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(fold_dir, "best_model.keras"),
        monitor="val_loss",
        save_best_only=True,
        mode="min",
        verbose=1
    )

    # ✅ Return both callbacks
    return [
        SaveEveryNEpochs(save_freq=save_every, folder=fold_dir),
        best_model_cb
    ]

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import f1_score

class F1ScoreCallback(tf.keras.callbacks.Callback):
    """
    Computes Macro F1 score for both disease and activity outputs
    at the end of each epoch during training.
    """
    def __init__(self, X_val, y_val_disease, y_val_activity, fold_no=None):
        super().__init__()
        self.X_val = X_val
        self.y_val_disease = y_val_disease
        self.y_val_activity = y_val_activity
        self.fold_no = fold_no

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        # Predict outputs
        y_pred_disease, y_pred_activity = self.model.predict(self.X_val, verbose=0)

        # Take argmax to get class predictions
        y_pred_disease = np.argmax(y_pred_disease, axis=1)
        y_pred_activity = np.argmax(y_pred_activity, axis=1)

        # Compute macro F1 scores
        f1_disease = f1_score(self.y_val_disease, y_pred_disease, average="macro")
        f1_activity = f1_score(self.y_val_activity, y_pred_activity, average="macro")

        fold_info = f" (Fold {self.fold_no})" if self.fold_no is not None else ""
        print(f"\n🔹 Epoch {epoch+1}{fold_info} - Val Macro F1 | Disease: {f1_disease:.4f} | Activity: {f1_activity:.4f}")

        # Add to logs for Keras monitoring
        logs["val_f1_disease"] = f1_disease
        logs["val_f1_activity"] = f1_activity

# %%
def compile_and_train(model,
                      X_train, y_disease_train, y_activity_train,
                      X_val, y_disease_val, y_activity_val,
                      fold_no,
                      base_lr=0.001,
                      batch_size=512,
                      epochs=100,
                      resume=True,
                      checkpoint_dir="/kaggle/working/checkpoints"):

    import tensorflow as tf
    import os

    # --- Compile the model for multi-task learning ---
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=base_lr),
        loss={
            "disease_output": "sparse_categorical_crossentropy",
            "activity_output": "sparse_categorical_crossentropy",
        },
        metrics={
            "disease_output": ["accuracy"],
            "activity_output": ["accuracy"],
        },
    )

    # --- Fold-specific checkpoint directory ---
    fold_dir = os.path.join(checkpoint_dir, f"fold_{fold_no}")
    os.makedirs(fold_dir, exist_ok=True)

    # --- Resume from last best checkpoint if available ---
    best_model_path = os.path.join(fold_dir, "best_model.keras")
    if resume and os.path.exists(best_model_path):
        print(f"🔁 Resuming training for Fold {fold_no} from: {best_model_path}")
        model.load_weights(best_model_path)
    else:
        print(f"🚀 Starting new training for Fold {fold_no}")

    # --- Callbacks ---
    callbacks = get_callbacks(checkpoint_dir=checkpoint_dir, fold_no=fold_no, save_every=10)

    # Add F1ScoreCallback
    f1_cb = F1ScoreCallback(
        X_val=X_val,
        y_val_disease=y_disease_val,
        y_val_activity=y_activity_val,
        fold_no=fold_no
    )
    callbacks.append(f1_cb)

    # --- Train the model ---
    history = model.fit(
        X_train,
        {"disease_output": y_disease_train, "activity_output": y_activity_train},
        validation_data=(X_val, {"disease_output": y_disease_val, "activity_output": y_activity_val}),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=1,
    )

    print(f"✅ Training complete for Fold {fold_no}. Best model saved in {fold_dir}")
    return history

# %%
# ====================================================
# 🔹 LOSO (Leave-One-Subject-Out) Cross-Validation
# ====================================================
import numpy as np
import pandas as pd
import os

# --- Get unique subjects ---
unique_subjects = np.unique(y_subject)
n_splits = len(unique_subjects)
fold_results = []

# --- Global checkpoint directory ---
BASE_CHECKPOINT_DIR = "/kaggle/working/checkpoints"
os.makedirs(BASE_CHECKPOINT_DIR, exist_ok=True)
print(f"✅ Checkpoints will be saved in: {BASE_CHECKPOINT_DIR}")

# ====================================================
# 🔁 LOSO Loop
# ====================================================
for fold_no, test_subject in enumerate(unique_subjects, 1):
    print(f"\n==============================")
    print(f"🔹 Fold {fold_no}/{n_splits} → Test Subject: {test_subject}")
    print(f"==============================")

    # ---- Split Data ----
    train_idx = np.where(y_subject != test_subject)[0]
    val_idx = np.where(y_subject == test_subject)[0]

    X_train_fold, X_val_fold = X_scaled[train_idx], X_scaled[val_idx]
    y_disease_train_fold, y_disease_val_fold = y_disease[train_idx], y_disease[val_idx]
    y_activity_train_fold, y_activity_val_fold = y_activity[train_idx], y_activity[val_idx]

    # ---- Model Parameters ----
    input_shape = (X_scaled.shape[1], X_scaled.shape[2])
    num_disease = len(np.unique(y_disease))
    num_activities = len(np.unique(y_activity))

    # ---- Build Model ----
    model = build_multi_task_model(
        timesteps=input_shape[0],
        features=input_shape[1],
        num_disease=num_disease,
        num_activities=num_activities,
    )

    # ✅ Create fold-specific checkpoint folder
    fold_checkpoint_dir = os.path.join(BASE_CHECKPOINT_DIR, f"fold_{fold_no}")
    os.makedirs(fold_checkpoint_dir, exist_ok=True)

    # ---- Train Model ----
    history = compile_and_train(
        model,
        X_train_fold, y_disease_train_fold, y_activity_train_fold,
        X_val_fold, y_disease_val_fold, y_activity_val_fold,
        fold_no=fold_no,
        base_lr=0.001,
        batch_size=512,
        epochs=100,
        resume=True,  # ✅ continue from saved weights if available
        checkpoint_dir=BASE_CHECKPOINT_DIR  # ✅ use global folder
    )

    # ---- Evaluate ----
    scores = model.evaluate(
        X_val_fold,
        {"disease_output": y_disease_val_fold, "activity_output": y_activity_val_fold},
        verbose=0,
        return_dict=True
    )

    # ---- Log Results ----
    fold_results.append({
        "fold": fold_no,
        "test_subject": test_subject,
        "val_loss": scores.get("loss"),
        "val_disease_acc": scores.get("disease_output_accuracy"),
        "val_activity_acc": scores.get("activity_output_accuracy")
    })

    print(f"✅ Fold {fold_no} Results → Disease Acc: {scores.get('disease_output_accuracy'):.4f} | "
          f"Activity Acc: {scores.get('activity_output_accuracy'):.4f}")

# ====================================================
# 📊 Summary of Results
# ====================================================
results_df = pd.DataFrame(fold_results)
print("\n📊 LOSO Cross-Validation Summary:")
print(results_df)

best_fold = results_df.loc[results_df["val_disease_acc"].idxmax()]
print(f"\n🏆 Best Fold: {int(best_fold.fold)} (Subject {best_fold.test_subject})")
print(f"   Disease Acc: {best_fold.val_disease_acc:.4f}")
print(f"   Activity Acc: {best_fold.val_activity_acc:.4f}")

print(f"\n📈 Average Disease Acc: {results_df.val_disease_acc.mean():.4f}")
print(f"📈 Average Activity Acc: {results_df.val_activity_acc.mean():.4f}")
# Out:
# ✅ Checkpoints will be saved in: /kaggle/working/checkpoints
#
# ==============================
# 🔹 Fold 1/18 → Test Subject: 1
# ==============================
# I0000 00:00:1763275575.297088      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1763275575.297792      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 🚀 Starting new training for Fold 1
# Epoch 1/100
# I0000 00:00:1763275585.863514      85 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - activity_output_accuracy: 0.3446 - activity_output_loss: 1.9422 - disease_output_accuracy: 0.4129 - disease_output_loss: 1.2460 - loss: 3.1914
# Epoch 1: val_loss improved from inf to 3.42613, saving model to /kaggle/working/checkpoints/fold_1/best_model.keras
#
# 🔹 Epoch 1 (Fold 1) - Val Macro F1 | Disease: 0.1819 | Activity: 0.1547
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 17s 274ms/step - activity_output_accuracy: 0.3484 - activity_output_loss: 1.9303 - disease_output_accuracy: 0.4144 - disease_output_loss: 1.2402 - loss: 3.1746 - val_activity_output_accuracy: 0.3041 - val_activity_output_loss: 2.7525 - val_disease_output_accuracy: 0.3752 - val_disease_output_loss: 1.4970 - val_loss: 3.4261 - val_f1_disease: 0.1819 - val_f1_activity: 0.1547
# Epoch 2/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - activity_output_accuracy: 0.5811 - activity_output_loss: 1.2713 - disease_output_accuracy: 0.5091 - disease_output_loss: 0.9839 - loss: 2.2575
# Epoch 2: val_loss improved from 3.42613 to 3.32575, saving model to /kaggle/working/checkpoints/fold_1/best_model.keras
#
# 🔹 Epoch 2 (Fold 1) - Val Macro F1 | Disease: 0.1693 | Activity: 0.1980
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - activity_output_accuracy: 0.5836 - activity_output_loss: 1.2656 - disease_output_accuracy: 0.5119 - disease_output_loss: 0.9807 - loss: 2.2481 - val_activity_output_accuracy: 0.3835 - val_activity_output_loss: 3.0489 - val_disease_output_accuracy: 0.3405 - val_disease_output_loss: 1.1911 - val_loss: 3.3257 - val_f1_disease: 0.1693 - val_f1_activity: 0.1980
# Epoch 3/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - activity_output_accuracy: 0.6718 - activity_output_loss: 1.0233 - disease_output_accuracy: 0.6197 - disease_output_loss: 0.8323 - loss: 1.8579
# Epoch 3: val_loss did not improve from 3.32575
#
# 🔹 Epoch 3 (Fold 1) - Val Macro F1 | Disease: 0.1535 | Activity: 0.2496
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - activity_output_accuracy: 0.6731 - activity_output_loss: 1.0192 - disease_output_accuracy: 0.6209 - disease_output_loss: 0.8304 - loss: 1.8525 - val_activity_output_accuracy: 0.3752 - val_activity_output_loss: 2.8670 - val_disease_output_accuracy: 0.2992 - val_disease_output_loss: 1.5437 - val_loss: 3.7233 - val_f1_disease: 0.1535 - val_f1_activity: 0.2496
# Epoch 4/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - activity_output_accuracy: 0.7249 - activity_output_loss: 0.8602 - disease_output_accuracy: 0.6646 - disease_output_loss: 0.7611 - loss: 1.6237
# Epoch 4: val_loss improved from 3.32575 to 3.28614, saving model to /kaggle/working/checkpoints/fold_1/best_model.keras
#
# 🔹 Epoch 4 (Fold 1) - Val Macro F1 | Disease: 0.1663 | Activity: 0.3044
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - activity_output_accuracy: 0.7255 - activity_output_loss: 0.8583 - disease_output_accuracy: 0.6665 - disease_output_loss: 0.7564 - loss: 1.6184 - val_activity_output_accuracy: 0.4281 - val_activity_output_loss: 2.5334 - val_disease_output_accuracy: 0.3322 - val_disease_output_loss: 1.3396 - val_loss: 3.2861 - val_f1_disease: 0.1663 - val_f1_activity: 0.3044
# Epoch 5/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - activity_output_accuracy: 0.7548 - activity_output_loss: 0.7805 - disease_output_accuracy: 0.7229 - disease_output_loss: 0.6557 - loss: 1.4386
# Epoch 5: val_loss did not improve from 3.28614
#
# 🔹 Epoch 5 (Fold 1) - Val Macro F1 | Disease: 0.1224 | Activity: 0.2893
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - activity_output_accuracy: 0.7553 - activity_output_loss: 0.7779 - disease_output_accuracy: 0.7242 - disease_output_loss: 0.6525 - loss: 1.4336 - val_activity_output_accuracy: 0.4231 - val_activity_output_loss: 2.3072 - val_disease_output_accuracy: 0.2248 - val_disease_output_loss: 1.8276 - val_loss: 3.8422 - val_f1_disease: 0.1224 - val_f1_activity: 0.2893
# Epoch 6/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - activity_output_accuracy: 0.7849 - activity_output_loss: 0.6884 - disease_output_accuracy: 0.7584 - disease_output_loss: 0.5805 - loss: 1.2713
# Epoch 6: val_loss did not improve from 3.28614
#
# 🔹 Epoch 6 (Fold 1) - Val Macro F1 | Disease: 0.1034 | Activity: 0.2912
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - activity_output_accuracy: 0.7852 - activity_output_loss: 0.6860 - disease_output_accuracy: 0.7591 - disease_output_loss: 0.5791 - loss: 1.2688 - val_activity_output_accuracy: 0.4248 - val_activity_output_loss: 2.1034 - val_disease_output_accuracy: 0.1835 - val_disease_output_loss: 2.4961 - val_loss: 4.4496 - val_f1_disease: 0.1034 - val_f1_activity: 0.2912
# Epoch 7/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - activity_output_accuracy: 0.8108 - activity_output_loss: 0.6049 - disease_output_accuracy: 0.8034 - disease_output_loss: 0.4945 - loss: 1.1019
# Epoch 7: val_loss did not improve from 3.28614
#
# 🔹 Epoch 7 (Fold 1) - Val Macro F1 | Disease: 0.1442 | Activity: 0.2771
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - activity_output_accuracy: 0.8112 - activity_output_loss: 0.6036 - disease_output_accuracy: 0.8043 - disease_output_loss: 0.4928 - loss: 1.0992 - val_activity_output_accuracy: 0.3702 - val_activity_output_loss: 1.9305 - val_disease_output_accuracy: 0.2760 - val_disease_output_loss: 2.4713 - val_loss: 3.9189 - val_f1_disease: 0.1442 - val_f1_activity: 0.2771
# Epoch 8/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - activity_output_accuracy: 0.9292 - activity_output_loss: 0.2404 - disease_output_accuracy: 0.9535 - disease_output_loss: 0.1415 - loss: 0.3844
# Epoch 17: val_loss did not improve from 3.28614
#
# 🔹 Epoch 17 (Fold 1) - Val Macro F1 | Disease: 0.1381 | Activity: 0.2990
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - activity_output_accuracy: 0.9293 - activity_output_loss: 0.2405 - disease_output_accuracy: 0.9536 - disease_output_loss: 0.1415 - loss: 0.3844 - val_activity_output_accuracy: 0.3818 - val_activity_output_loss: 2.6888 - val_disease_output_accuracy: 0.2612 - val_disease_output_loss: 2.7199 - val_loss: 5.3964 - val_f1_disease: 0.1381 - val_f1_activity: 0.2990
# Epoch 18/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - activity_output_accuracy: 0.9348 - activity_output_loss: 0.2326 - disease_output_accuracy: 0.9570 - disease_output_loss: 0.1336 - loss: 0.3688
# Epoch 18: val_loss did not improve from 3.28614
#
# 🔹 Epoch 18 (Fold 1) - Val Macro F1 | Disease: 0.1367 | Activity: 0.3285
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - activity_output_accuracy: 0.9347 - activity_output_loss: 0.2319 - disease_output_accuracy: 0.9572 - disease_output_loss: 0.1334 - loss: 0.3678 - val_activity_output_accuracy: 0.4612 - val_activity_output_loss: 2.4973 - val_disease_output_accuracy: 0.2579 - val_disease_output_loss: 3.2657 - val_loss: 5.4883 - val_f1_disease: 0.1367 - val_f1_activity: 0.3285
# Epoch 19/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - activity_output_accuracy: 0.9284 - activity_output_loss: 0.2228 - disease_output_accuracy: 0.9612 - disease_output_loss: 0.1231 - loss: 0.3484
# Epoch 19: val_loss did not improve from 3.28614
#
# 🔹 Epoch 19 (Fold 1) - Val Macro F1 | Disease: 0.1346 | Activity: 0.3219
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - activity_output_accuracy: 0.9289 - activity_output_loss: 0.2224 - disease_output_accuracy: 0.9612 - disease_output_loss: 0.1227 - loss: 0.3477 - val_activity_output_accuracy: 0.4595 - val_activity_output_loss: 2.5001 - val_disease_output_accuracy: 0.2529 - val_disease_output_loss: 3.0946 - val_loss: 5.0748 - val_f1_disease: 0.1346 - val_f1_activity: 0.3219
# Epoch 20/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - activity_output_accuracy: 0.9437 - activity_output_loss: 0.1929 - disease_output_accuracy: 0.9734 - disease_output_loss: 0.0904 - loss: 0.2859
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_1/epoch_020_valLoss_5.3750.keras
#
# Epoch 20: val_loss did not improve from 3.28614
#
# 🔹 Epoch 20 (Fold 1) - Val Macro F1 | Disease: 0.1580 | Activity: 0.3047
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - activity_output_accuracy: 0.9441 - activity_output_loss: 0.1919 - disease_output_accuracy: 0.9734 - disease_output_loss: 0.0902 - loss: 0.2850 - val_activity_output_accuracy: 0.4512 - val_activity_output_loss: 2.7707 - val_disease_output_accuracy: 0.3107 - val_disease_output_loss: 2.8010 - val_loss: 5.3750 - val_f1_disease: 0.1580 - val_f1_activity: 0.3047
# Epoch 21/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - activity_output_accuracy: 0.9527 - activity_output_loss: 0.1663 - disease_output_accuracy: 0.9760 - disease_output_loss: 0.0825 - loss: 0.2514
# Epoch 21: val_loss did not improve from 3.28614
#
# 🔹 Epoch 21 (Fold 1) - Val Macro F1 | Disease: 0.1422 | Activity: 0.3243
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step
100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - activity_output_accuracy: 0.9623 - activity_output_loss: 0.1307 - disease_output_accuracy: 0.9765 - disease_output_loss: 0.0671 - loss: 0.2004
# Epoch 26: val_loss did not improve from 3.28614
#
# 🔹 Epoch 26 (Fold 1) - Val Macro F1 | Disease: 0.1415 | Activity: 0.2468
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - activity_output_accuracy: 0.9625 - activity_output_loss: 0.1301 - disease_output_accuracy: 0.9768 - disease_output_loss: 0.0668 - loss: 0.2000 - val_activity_output_accuracy: 0.2992 - val_activity_output_loss: 4.0215 - val_disease_output_accuracy: 0.2694 - val_disease_output_loss: 3.9621 - val_loss: 7.2436 - val_f1_disease: 0.1415 - val_f1_activity: 0.2468
# Epoch 27/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - activity_output_accuracy: 0.9662 - activity_output_loss: 0.1184 - disease_output_accuracy: 0.9849 - disease_output_loss: 0.0531 - loss: 0.1741
# Epoch 27: val_loss did not improve from 3.28614
#
# 🔹 Epoch 27 (Fold 1) - Val Macro F1 | Disease: 0.1224 | Activity: 0.2575
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - activity_output_accuracy: 0.9663 - activity_output_loss: 0.1184 - disease_output_accuracy: 0.9851 - disease_output_loss: 0.0524 - loss: 0.1734 - val_activity_output_accuracy: 0.3421 - val_activity_output_loss: 4.1620 - val_disease_output_accuracy: 0.2248 - val_disease_output_loss: 3.8589 - val_loss: 7.6006 - val_f1_disease: 0.1224 - val_f1_activity: 0.2575
# Epoch 28/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - activity_output_accuracy: 0.9711 - activity_output_loss: 0.1053 - disease_output_accuracy: 0.9858 - disease_output_loss: 0.0502 - loss: 0.1581
# Epoch 28: val_loss did not improve from 3.28614
#
# 🔹 Epoch 28 (Fold 1) - Val Macro F1 | Disease: 0.1482 | Activity: 0.3298
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - activity_output_accuracy: 0.9709 - activity_output_loss: 0.1057 - disease_output_accuracy: 0.9860 - disease_output_loss: 0.0497 - loss: 0.1582 - val_activity_output_accuracy: 0.4496 - val_activity_output_loss: 3.0382 - val_disease_output_accuracy: 0.2860 - val_disease_output_loss: 4.3820 - val_loss: 6.9085 - val_f1_disease: 0.1482 - val_f1_activity: 0.3298
# Epoch 29/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - activity_output_accuracy: 0.9731 - activity_output_loss: 0.0981 - disease_output_accuracy: 0.9855 - disease_output_loss: 0.0453 - loss: 0.1461
# Epoch 29: val_loss did not improve from 3.28614
#
# 🔹 Epoch 29 (Fold 1) - Val Macro F1 | Disease: 0.1422 | Activity: 0.3122
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - activity_output_accuracy: 0.9734 - activity_output_loss: 0.0979 - disease_output_accuracy: 0.9856 - disease_output_loss: 0.0452 - loss: 0.1456 - val_activity_output_accuracy: 0.4331 - val_activity_output_loss: 3.5432 - val_disease_output_accuracy: 0.2711 - val_disease_output_loss: 4.1350 - val_loss: 7.2141 - val_f1_disease: 0.1422 - val_f1_activity: 0.3122
# Epoch 30/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - activity_output_accuracy: 0.9746 - activity_output_loss: 0.0937 - disease_output_accuracy: 0.9855 - disease_output_loss: 0.0527 - loss: 0.1490
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_1/epoch_030_valLoss_6.6497.keras
#
# Epoch 30: val_loss did not improve from 3.28614
#
# 🔹 Epoch 30 (Fold 1) - Val Macro F1 | Disease: 0.1619 | Activity: 0.2472
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step
100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - activity_output_accuracy: 0.9699 - activity_output_loss: 0.0918 - disease_output_accuracy: 0.9834 - disease_output_loss: 0.0530 - loss: 0.1475
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_1/epoch_040_valLoss_8.4522.keras
#
# Epoch 40: val_loss did not improve from 3.28614
#
# 🔹 Epoch 40 (Fold 1) - Val Macro F1 | Disease: 0.1142 | Activity: 0.2838
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - activity_output_accuracy: 0.9702 - activity_output_loss: 0.0912 - disease_output_accuracy: 0.9835 - disease_output_loss: 0.0524 - loss: 0.1464 - val_activity_output_accuracy: 0.4215 - val_activity_output_loss: 3.7590 - val_disease_output_accuracy: 0.2066 - val_disease_output_loss: 4.6749 - val_loss: 8.4522 - val_f1_disease: 0.1142 - val_f1_activity: 0.2838
# Epoch 41/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - activity_output_accuracy: 0.9804 - activity_output_loss: 0.0721 - disease_output_accuracy: 0.9836 - disease_output_loss: 0.0532 - loss: 0.1280
# Epoch 41: val_loss did not improve from 3.28614
#
# 🔹 Epoch 41 (Fold 1) - Val Macro F1 | Disease: 0.1339 | Activity: 0.2683
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - activity_output_accuracy: 0.9803 - activity_output_loss: 0.0725 - disease_output_accuracy: 0.9837 - disease_output_loss: 0.0526 - loss: 0.1277 - val_activity_output_accuracy: 0.4149 - val_activity_output_loss: 4.3892 - val_disease_output_accuracy: 0.2512 - val_disease_output_loss: 5.3501 - val_loss: 8.8471 - val_f1_disease: 0.1339 - val_f1_activity: 0.2683
# Epoch 42/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - activity_output_accuracy: 0.9819 - activity_output_loss: 0.0670 - disease_output_accuracy: 0.9940 - disease_output_loss: 0.0238 - loss: 0.0936
# Epoch 42: val_loss did not improve from 3.28614
#
# 🔹 Epoch 42 (Fold 1) - Val Macro F1 | Disease: 0.1275 | Activity: 0.2898
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - activity_output_accuracy: 0.9818 - activity_output_loss: 0.0670 - disease_output_accuracy: 0.9940 - disease_output_loss: 0.0237 - loss: 0.0937 - val_activity_output_accuracy: 0.4264 - val_activity_output_loss: 4.1373 - val_disease_output_accuracy: 0.2364 - val_disease_output_loss: 3.6559 - val_loss: 8.1320 - val_f1_disease: 0.1275 - val_f1_activity: 0.2898
# Epoch 43/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - activity_output_accuracy: 0.9864 - activity_output_loss: 0.0517 - disease_output_accuracy: 0.9931 - disease_output_loss: 0.0226 - loss: 0.0771
# Epoch 43: val_loss did not improve from 3.28614
#
# 🔹 Epoch 43 (Fold 1) - Val Macro F1 | Disease: 0.1489 | Activity: 0.2556
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - activity_output_accuracy: 0.9864 - activity_output_loss: 0.0525 - disease_output_accuracy: 0.9932 - disease_output_loss: 0.0225 - loss: 0.0771 - val_activity_output_accuracy: 0.4050 - val_activity_output_loss: 3.8910 - val_disease_output_accuracy: 0.2876 - val_disease_output_loss: 4.5348 - val_loss: 8.1674 - val_f1_disease: 0.1489 - val_f1_activity: 0.2556
# Epoch 44/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - activity_output_accuracy: 0.9830 - activity_output_loss: 0.0562 - disease_output_accuracy: 0.9916 - disease_output_loss: 0.0276 - loss: 0.0865
# Epoch 44: val_loss did not improve from 3.28614
#
# 🔹 Epoch 44 (Fold 1) - Val Macro F1 | Disease: 0.1415 | Activity: 0.3203
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step
100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9855 - activity_output_loss: 0.0517 - disease_output_accuracy: 0.9876 - disease_output_loss: 0.0432 - loss: 0.0976
# Epoch 49: val_loss did not improve from 3.28614
#
# 🔹 Epoch 49 (Fold 1) - Val Macro F1 | Disease: 0.1317 | Activity: 0.2665
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9856 - activity_output_loss: 0.0515 - disease_output_accuracy: 0.9877 - disease_output_loss: 0.0425 - loss: 0.0966 - val_activity_output_accuracy: 0.4033 - val_activity_output_loss: 4.4547 - val_disease_output_accuracy: 0.2463 - val_disease_output_loss: 4.6901 - val_loss: 8.9621 - val_f1_disease: 0.1317 - val_f1_activity: 0.2665
# Epoch 50/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9852 - activity_output_loss: 0.0480 - disease_output_accuracy: 0.9943 - disease_output_loss: 0.0225 - loss: 0.0733
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_1/epoch_050_valLoss_8.7378.keras
#
# Epoch 50: val_loss did not improve from 3.28614
#
# 🔹 Epoch 50 (Fold 1) - Val Macro F1 | Disease: 0.1267 | Activity: 0.2710
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - activity_output_accuracy: 0.9854 - activity_output_loss: 0.0478 - disease_output_accuracy: 0.9943 - disease_output_loss: 0.0224 - loss: 0.0730 - val_activity_output_accuracy: 0.3719 - val_activity_output_loss: 4.7866 - val_disease_output_accuracy: 0.2347 - val_disease_output_loss: 4.3722 - val_loss: 8.7378 - val_f1_disease: 0.1267 - val_f1_activity: 0.2710
# Epoch 51/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9890 - activity_output_loss: 0.0399 - disease_output_accuracy: 0.9938 - disease_output_loss: 0.0212 - loss: 0.0640
# Epoch 51: val_loss did not improve from 3.28614
#
# 🔹 Epoch 51 (Fold 1) - Val Macro F1 | Disease: 0.1367 | Activity: 0.2662
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9889 - activity_output_loss: 0.0401 - disease_output_accuracy: 0.9939 - disease_output_loss: 0.0211 - loss: 0.0639 - val_activity_output_accuracy: 0.4033 - val_activity_output_loss: 4.9985 - val_disease_output_accuracy: 0.2579 - val_disease_output_loss: 5.1475 - val_loss: 9.5311 - val_f1_disease: 0.1367 - val_f1_activity: 0.2662
# Epoch 52/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9801 - activity_output_loss: 0.0614 - disease_output_accuracy: 0.9932 - disease_output_loss: 0.0226 - loss: 0.0868
# Epoch 52: val_loss did not improve from 3.28614
#
# 🔹 Epoch 52 (Fold 1) - Val Macro F1 | Disease: 0.1282 | Activity: 0.2416
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9804 - activity_output_loss: 0.0606 - disease_output_accuracy: 0.9933 - disease_output_loss: 0.0225 - loss: 0.0861 - val_activity_output_accuracy: 0.3256 - val_activity_output_loss: 4.1899 - val_disease_output_accuracy: 0.2380 - val_disease_output_loss: 5.2777 - val_loss: 9.2363 - val_f1_disease: 0.1282 - val_f1_activity: 0.2416
# Epoch 53/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9899 - activity_output_loss: 0.0359 - disease_output_accuracy: 0.9947 - disease_output_loss: 0.0214 - loss: 0.0601
# Epoch 53: val_loss did not improve from 3.28614
#
# 🔹 Epoch 53 (Fold 1) - Val Macro F1 | Disease: 0.1429 | Activity: 0.2606
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9899 - activity_output_loss: 0.0360 - disease_output_accuracy: 0.9947 - disease_output_loss: 0.0214 - loss: 0.0603 - val_activity_output_accuracy: 0.3983 - val_activity_output_loss: 4.9060 - val_disease_output_accuracy: 0.2727 - val_disease_output_loss: 3.5359 - val_loss: 8.2858 - val_f1_disease: 0.1429 - val_f1_activity: 0.2606
# Epoch 54/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9898 - activity_output_loss: 0.0358 - disease_output_accuracy: 0.9942 - disease_output_loss: 0.0176 - loss: 0.0562
# Epoch 54: val_loss did not improve from 3.28614
#
# 🔹 Epoch 54 (Fold 1) - Val Macro F1 | Disease: 0.1489 | Activity: 0.2893
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9899 - activity_output_loss: 0.0357 - disease_output_accuracy: 0.9942 - disease_output_loss: 0.0175 - loss: 0.0560 - val_activity_output_accuracy: 0.4264 - val_activity_output_loss: 4.3418 - val_disease_output_accuracy: 0.2876 - val_disease_output_loss: 3.9994 - val_loss: 8.2048 - val_f1_disease: 0.1489 - val_f1_activity: 0.2893
# Epoch 55/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9864 - activity_output_loss: 0.0422 - disease_output_accuracy: 0.9978 - disease_output_loss: 0.0123 - loss: 0.0573
# Epoch 55: val_loss did not improve from 3.28614
#
# 🔹 Epoch 55 (Fold 1) - Val Macro F1 | Disease: 0.1387 | Activity: 0.2736
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9866 - activity_output_loss: 0.0416 - disease_output_accuracy: 0.9978 - disease_output_loss: 0.0123 - loss: 0.0568 - val_activity_output_accuracy: 0.3934 - val_activity_output_loss: 4.8196 - val_disease_output_accuracy: 0.2628 - val_disease_output_loss: 3.8678 - val_loss: 8.8503 - val_f1_disease: 0.1387 - val_f1_activity: 0.2736
# Epoch 56/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9876 - activity_output_loss: 0.0393 - disease_output_accuracy: 0.9883 - disease_output_loss: 0.0380 - loss: 0.0801
# Epoch 56: val_loss did not improve from 3.28614
#
# 🔹 Epoch 56 (Fold 1) - Val Macro F1 | Disease: 0.1282 | Activity: 0.2575
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9876 - activity_output_loss: 0.0393 - disease_output_accuracy: 0.9883 - disease_output_loss: 0.0376 - loss: 0.0799 - val_activity_output_accuracy: 0.3736 - val_activity_output_loss: 4.8271 - val_disease_output_accuracy: 0.2380 - val_disease_output_loss: 4.2657 - val_loss: 9.1452 - val_f1_disease: 0.1282 - val_f1_activity: 0.2575
# Epoch 57/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9890 - activity_output_loss: 0.0399 - disease_output_accuracy: 0.9939 - disease_output_loss: 0.0179 - loss: 0.0605
# Epoch 57: val_loss did not improve from 3.28614
#
# 🔹 Epoch 57 (Fold 1) - Val Macro F1 | Disease: 0.1179 | Activity: 0.3367
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9889 - activity_output_loss: 0.0398 - disease_output_accuracy: 0.9940 - disease_output_loss: 0.0176 - loss: 0.0603 - val_activity_output_accuracy: 0.4397 - val_activity_output_loss: 4.6960 - val_disease_output_accuracy: 0.2149 - val_disease_output_loss: 4.8909 - val_loss: 9.8950 - val_f1_disease: 0.1179 - val_f1_activity: 0.3367
# Epoch 58/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9911 - activity_output_loss: 0.0346 - disease_output_accuracy: 0.9969 - disease_output_loss: 0.0129 - loss: 0.0502
# Epoch 58: val_loss did not improve from 3.28614
#
# 🔹 Epoch 58 (Fold 1) - Val Macro F1 | Disease: 0.1317 | Activity: 0.3136
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9910 - activity_output_loss: 0.0345 - disease_output_accuracy: 0.9968 - disease_output_loss: 0.0129 - loss: 0.0503 - val_activity_output_accuracy: 0.4496 - val_activity_output_loss: 4.2161 - val_disease_output_accuracy: 0.2463 - val_disease_output_loss: 4.3601 - val_loss: 8.6296 - val_f1_disease: 0.1317 - val_f1_activity: 0.3136
# Epoch 59/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9916 - activity_output_loss: 0.0299 - disease_output_accuracy: 0.9961 - disease_output_loss: 0.0150 - loss: 0.0477
# Epoch 59: val_loss did not improve from 3.28614
#
# 🔹 Epoch 59 (Fold 1) - Val Macro F1 | Disease: 0.1260 | Activity: 0.2600
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9915 - activity_output_loss: 0.0300 - disease_output_accuracy: 0.9962 - disease_output_loss: 0.0148 - loss: 0.0478 - val_activity_output_accuracy: 0.3570 - val_activity_output_loss: 4.2424 - val_disease_output_accuracy: 0.2331 - val_disease_output_loss: 4.5904 - val_loss: 8.9468 - val_f1_disease: 0.1260 - val_f1_activity: 0.2600
# Epoch 60/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - activity_output_accuracy: 0.9928 - activity_output_loss: 0.0268 - disease_output_accuracy: 0.9971 - disease_output_loss: 0.0128 - loss: 0.0424
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_1/epoch_060_valLoss_9.7468.keras
#
# Epoch 60: val_loss did not improve from 3.28614
#
# 🔹 Epoch 60 (Fold 1) - Val Macro F1 | Disease: 0.1289 | Activity: 0.2628
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - activity_output_accuracy: 0.9927 - activity_output_loss: 0.0269 - disease_output_accuracy: 0.9972 - disease_output_loss: 0.0127 - loss: 0.0425 - val_activity_output_accuracy: 0.3355 - val_activity_output_loss: 4.5725 - val_disease_output_accuracy: 0.2397 - val_disease_output_loss: 5.5118 - val_loss: 9.7468 - val_f1_disease: 0.1289 - val_f1_activity: 0.2628
# Epoch 61/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9926 - activity_output_loss: 0.0266 - disease_output_accuracy: 0.9973 - disease_output_loss: 0.0130 - loss: 0.0424
# Epoch 61: val_loss did not improve from 3.28614
#
# 🔹 Epoch 61 (Fold 1) - Val Macro F1 | Disease: 0.1790 | Activity: 0.2855
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9925 - activity_output_loss: 0.0271 - disease_output_accuracy: 0.9972 - disease_output_loss: 0.0134 - loss: 0.0431 - val_activity_output_accuracy: 0.4331 - val_activity_output_loss: 4.8271 - val_disease_output_accuracy: 0.3669 - val_disease_output_loss: 5.1037 - val_loss: 8.3457 - val_f1_disease: 0.1790 - val_f1_activity: 0.2855
# Epoch 62/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - activity_output_accuracy: 0.9829 - activity_output_loss: 0.0560 - disease_output_accuracy: 0.9826 - disease_output_loss: 0.0607 - loss: 0.1195
# Epoch 62: val_loss did not improve from 3.28614
#
# 🔹 Epoch 62 (Fold 1) - Val Macro F1 | Disease: 0.1164 | Activity: 0.2350
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - activity_output_accuracy: 0.9830 - activity_output_loss: 0.0555 - disease_output_accuracy: 0.9830 - disease_output_loss: 0.0589 - loss: 0.1174 - val_activity_output_accuracy: 0.4050 - val_activity_output_loss: 5.1689 - val_disease_output_accuracy: 0.2116 - val_disease_output_loss: 5.5372 - val_loss: 10.5509 - val_f1_disease: 0.1164 - val_f1_activity: 0.2350
# Epoch 63/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9862 - activity_output_loss: 0.0409 - disease_output_accuracy: 0.9917 - disease_output_loss: 0.0263 - loss: 0.0700
# Epoch 63: val_loss did not improve from 3.28614
#
# 🔹 Epoch 63 (Fold 1) - Val Macro F1 | Disease: 0.1325 | Activity: 0.2993
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9863 - activity_output_loss: 0.0408 - disease_output_accuracy: 0.9919 - disease_output_loss: 0.0263 - loss: 0.0696 - val_activity_output_accuracy: 0.4215 - val_activity_output_loss: 4.0409 - val_disease_output_accuracy: 0.2479 - val_disease_output_loss: 5.6153 - val_loss: 9.5892 - val_f1_disease: 0.1325 - val_f1_activity: 0.2993
# Epoch 64/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9869 - activity_output_loss: 0.0412 - disease_output_accuracy: 0.9874 - disease_output_loss: 0.0343 - loss: 0.0783
# Epoch 64: val_loss did not improve from 3.28614
#
# 🔹 Epoch 64 (Fold 1) - Val Macro F1 | Disease: 0.1353 | Activity: 0.3397
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9870 - activity_output_loss: 0.0411 - disease_output_accuracy: 0.9877 - disease_output_loss: 0.0336 - loss: 0.0776 - val_activity_output_accuracy: 0.4281 - val_activity_output_loss: 4.0934 - val_disease_output_accuracy: 0.2545 - val_disease_output_loss: 4.5815 - val_loss: 8.2199 - val_f1_disease: 0.1353 - val_f1_activity: 0.3397
# Epoch 65/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9884 - activity_output_loss: 0.0369 - disease_output_accuracy: 0.9945 - disease_output_loss: 0.0180 - loss: 0.0578
# Epoch 65: val_loss did not improve from 3.28614
#
# 🔹 Epoch 65 (Fold 1) - Val Macro F1 | Disease: 0.1522 | Activity: 0.2565
# ...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9548 - activity_output_loss: 0.1498 - disease_output_accuracy: 0.9532 - disease_output_loss: 0.1449 - loss: 0.2975 - val_activity_output_accuracy: 0.6711 - val_activity_output_loss: 2.4925 - val_disease_output_accuracy: 0.4975 - val_disease_output_loss: 1.3684 - val_loss: 3.3637 - val_f1_disease: 0.2215 - val_f1_activity: 0.6002
# Epoch 26/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9571 - activity_output_loss: 0.1427 - disease_output_accuracy: 0.9733 - disease_output_loss: 0.0812 - loss: 0.2266
# Epoch 26: val_loss did not improve from 1.97052
#
# 🔹 Epoch 26 (Fold 18) - Val Macro F1 | Disease: 0.2099 | Activity: 0.6181
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9576 - activity_output_loss: 0.1417 - disease_output_accuracy: 0.9735 - disease_output_loss: 0.0809 - loss: 0.2256 - val_activity_output_accuracy: 0.6793 - val_activity_output_loss: 2.2405 - val_disease_output_accuracy: 0.4595 - val_disease_output_loss: 1.5458 - val_loss: 3.4996 - val_f1_disease: 0.2099 - val_f1_activity: 0.6181
# Epoch 27/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - activity_output_accuracy: 0.9675 - activity_output_loss: 0.1206 - disease_output_accuracy: 0.9775 - disease_output_loss: 0.0731 - loss: 0.1964
# Epoch 27: val_loss did not improve from 1.97052
#
# 🔹 Epoch 27 (Fold 18) - Val Macro F1 | Disease: 0.2036 | Activity: 0.6136
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - activity_output_accuracy: 0.9677 - activity_output_loss: 0.1201 - disease_output_accuracy: 0.9777 - disease_output_loss: 0.0726 - loss: 0.1953 - val_activity_output_accuracy: 0.6975 - val_activity_output_loss: 2.6106 - val_disease_output_accuracy: 0.4397 - val_disease_output_loss: 1.5298 - val_loss: 3.5769 - val_f1_disease: 0.2036 - val_f1_activity: 0.6136
# Epoch 28/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - activity_output_accuracy: 0.9761 - activity_output_loss: 0.0959 - disease_output_accuracy: 0.9849 - disease_output_loss: 0.0518 - loss: 0.1504
# Epoch 28: val_loss did not improve from 1.97052
#
# 🔹 Epoch 28 (Fold 18) - Val Macro F1 | Disease: 0.1760 | Activity: 0.6424
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - activity_output_accuracy: 0.9761 - activity_output_loss: 0.0962 - disease_output_accuracy: 0.9850 - disease_output_loss: 0.0516 - loss: 0.1505 - val_activity_output_accuracy: 0.7091 - val_activity_output_loss: 2.5791 - val_disease_output_accuracy: 0.3587 - val_disease_output_loss: 2.1143 - val_loss: 4.2804 - val_f1_disease: 0.1760 - val_f1_activity: 0.6424
# Epoch 29/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - activity_output_accuracy: 0.9695 - activity_output_loss: 0.1100 - disease_output_accuracy: 0.9857 - disease_output_loss: 0.0504 - loss: 0.1630
# Epoch 29: val_loss did not improve from 1.97052
#
# 🔹 Epoch 29 (Fold 18) - Val Macro F1 | Disease: 0.2165 | Activity: 0.6561
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9697 - activity_output_loss: 0.1093 - disease_output_accuracy: 0.9856 - disease_output_loss: 0.0506 - loss: 0.1624 - val_activity_output_accuracy: 0.7322 - val_activity_output_loss: 2.3966 - val_disease_output_accuracy: 0.4810 - val_disease_output_loss: 1.3965 - val_loss: 3.5064 - val_f1_disease: 0.2165 - val_f1_activity: 0.6561
# Epoch 30/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - activity_output_accuracy: 0.9733 - activity_output_loss: 0.1023 - disease_output_accuracy: 0.9843 - disease_output_loss: 0.0519 - loss: 0.1569
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_18/epoch_030_valLoss_3.6153.keras
#
# Epoch 30: val_loss did not improve from 1.97052
#
# 🔹 Epoch 30 (Fold 18) - Val Macro F1 | Disease: 0.2160 | Activity: 0.6234
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - activity_output_accuracy: 0.9732 - activity_output_loss: 0.1020 - disease_output_accuracy: 0.9844 - disease_output_loss: 0.0515 - loss: 0.1565 - val_activity_output_accuracy: 0.6860 - val_activity_output_loss: 2.5386 - val_disease_output_accuracy: 0.4793 - val_disease_output_loss: 1.5212 - val_loss: 3.6153 - val_f1_disease: 0.2160 - val_f1_activity: 0.6234
# Epoch 31/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9762 - activity_output_loss: 0.0835 - disease_output_accuracy: 0.9895 - disease_output_loss: 0.0392 - loss: 0.1254
# Epoch 31: val_loss did not improve from 1.97052
#
# 🔹 Epoch 31 (Fold 18) - Val Macro F1 | Disease: 0.1819 | Activity: 0.6391
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9764 - activity_output_loss: 0.0835 - disease_output_accuracy: 0.9895 - disease_output_loss: 0.0392 - loss: 0.1252 - val_activity_output_accuracy: 0.7174 - val_activity_output_loss: 2.4551 - val_disease_output_accuracy: 0.3752 - val_disease_output_loss: 1.9334 - val_loss: 4.0659 - val_f1_disease: 0.1819 - val_f1_activity: 0.6391
# Epoch 32/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9713 - activity_output_loss: 0.1008 - disease_output_accuracy: 0.9847 - disease_output_loss: 0.0486 - loss: 0.1521
# Epoch 32: val_loss did not improve from 1.97052
#
# 🔹 Epoch 32 (Fold 18) - Val Macro F1 | Disease: 0.1966 | Activity: 0.6327
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9714 - activity_output_loss: 0.1002 - disease_output_accuracy: 0.9848 - disease_output_loss: 0.0484 - loss: 0.1515 - val_activity_output_accuracy: 0.7041 - val_activity_output_loss: 2.6170 - val_disease_output_accuracy: 0.4182 - val_disease_output_loss: 1.7845 - val_loss: 3.9405 - val_f1_disease: 0.1966 - val_f1_activity: 0.6327
# Epoch 33/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9780 - activity_output_loss: 0.0811 - disease_output_accuracy: 0.9882 - disease_output_loss: 0.0413 - loss: 0.1251
# Epoch 33: val_loss did not improve from 1.97052
#
# 🔹 Epoch 33 (Fold 18) - Val Macro F1 | Disease: 0.1871 | Activity: 0.6447
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9782 - activity_output_loss: 0.0807 - disease_output_accuracy: 0.9882 - disease_output_loss: 0.0413 - loss: 0.1248 - val_activity_output_accuracy: 0.7157 - val_activity_output_loss: 2.6124 - val_disease_output_accuracy: 0.3901 - val_disease_output_loss: 1.9717 - val_loss: 4.1777 - val_f1_disease: 0.1871 - val_f1_activity: 0.6447
# Epoch 34/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9789 - activity_output_loss: 0.0746 - disease_output_accuracy: 0.9881 - disease_output_loss: 0.0401 - loss: 0.1174
# Epoch 34: val_loss did not improve from 1.97052
#
# 🔹 Epoch 34 (Fold 18) - Val Macro F1 | Disease: 0.1888 | Activity: 0.6583
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9789 - activity_output_loss: 0.0747 - disease_output_accuracy: 0.9882 - disease_output_loss: 0.0397 - loss: 0.1172 - val_activity_output_accuracy: 0.7322 - val_activity_output_loss: 2.6911 - val_disease_output_accuracy: 0.3950 - val_disease_output_loss: 1.9249 - val_loss: 4.2223 - val_f1_disease: 0.1888 - val_f1_activity: 0.6583
# Epoch 35/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9774 - activity_output_loss: 0.0809 - disease_output_accuracy: 0.9897 - disease_output_loss: 0.0329 - loss: 0.1165
# Epoch 35: val_loss did not improve from 1.97052
#
# 🔹 Epoch 35 (Fold 18) - Val Macro F1 | Disease: 0.1955 | Activity: 0.6173
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9774 - activity_output_loss: 0.0805 - disease_output_accuracy: 0.9897 - disease_output_loss: 0.0329 - loss: 0.1164 - val_activity_output_accuracy: 0.6909 - val_activity_output_loss: 2.5285 - val_disease_output_accuracy: 0.4149 - val_disease_output_loss: 1.6456 - val_loss: 3.8867 - val_f1_disease: 0.1955 - val_f1_activity: 0.6173
# Epoch 36/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9799 - activity_output_loss: 0.0724 - disease_output_accuracy: 0.9899 - disease_output_loss: 0.0341 - loss: 0.1092
# Epoch 36: val_loss did not improve from 1.97052
#
# 🔹 Epoch 36 (Fold 18) - Val Macro F1 | Disease: 0.2031 | Activity: 0.6493
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9798 - activity_output_loss: 0.0724 - disease_output_accuracy: 0.9899 - disease_output_loss: 0.0340 - loss: 0.1092 - val_activity_output_accuracy: 0.7107 - val_activity_output_loss: 2.6405 - val_disease_output_accuracy: 0.4380 - val_disease_output_loss: 1.8152 - val_loss: 3.9008 - val_f1_disease: 0.2031 - val_f1_activity: 0.6493
# Epoch 37/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9825 - activity_output_loss: 0.0686 - disease_output_accuracy: 0.9953 - disease_output_loss: 0.0231 - loss: 0.0945
# Epoch 37: val_loss did not improve from 1.97052
#
# 🔹 Epoch 37 (Fold 18) - Val Macro F1 | Disease: 0.1561 | Activity: 0.6449
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9824 - activity_output_loss: 0.0687 - disease_output_accuracy: 0.9953 - disease_output_loss: 0.0234 - loss: 0.0945 - val_activity_output_accuracy: 0.7289 - val_activity_output_loss: 2.6483 - val_disease_output_accuracy: 0.3058 - val_disease_output_loss: 2.1971 - val_loss: 4.7243 - val_f1_disease: 0.1561 - val_f1_activity: 0.6449
# Epoch 38/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - activity_output_accuracy: 0.9760 - activity_output_loss: 0.0799 - disease_output_accuracy: 0.9814 - disease_output_loss: 0.0560 - loss: 0.1386
# Epoch 38: val_loss did not improve from 1.97052
#
# 🔹 Epoch 38 (Fold 18) - Val Macro F1 | Disease: 0.1916 | Activity: 0.6095
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9761 - activity_output_loss: 0.0795 - disease_output_accuracy: 0.9816 - disease_output_loss: 0.0555 - loss: 0.1380 - val_activity_output_accuracy: 0.6777 - val_activity_output_loss: 2.6346 - val_disease_output_accuracy: 0.4033 - val_disease_output_loss: 1.8828 - val_loss: 4.2271 - val_f1_disease: 0.1916 - val_f1_activity: 0.6095
# Epoch 39/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9790 - activity_output_loss: 0.0663 - disease_output_accuracy: 0.9856 - disease_output_loss: 0.0406 - loss: 0.1097
# Epoch 39: val_loss did not improve from 1.97052
#
# 🔹 Epoch 39 (Fold 18) - Val Macro F1 | Disease: 0.2004 | Activity: 0.6452
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9791 - activity_output_loss: 0.0662 - disease_output_accuracy: 0.9857 - disease_output_loss: 0.0401 - loss: 0.1092 - val_activity_output_accuracy: 0.7107 - val_activity_output_loss: 2.5988 - val_disease_output_accuracy: 0.4298 - val_disease_output_loss: 1.8968 - val_loss: 4.2506 - val_f1_disease: 0.2004 - val_f1_activity: 0.6452
# Epoch 40/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9850 - activity_output_loss: 0.0581 - disease_output_accuracy: 0.9939 - disease_output_loss: 0.0242 - loss: 0.0850
# 💾 Checkpoint saved at: /kaggle/working/checkpoints/fold_18/epoch_040_valLoss_3.9282.keras
#
# Epoch 40: val_loss did not improve from 1.97052
#
# 🔹 Epoch 40 (Fold 18) - Val Macro F1 | Disease: 0.2160 | Activity: 0.6275
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - activity_output_accuracy: 0.9849 - activity_output_loss: 0.0582 - disease_output_accuracy: 0.9939 - disease_output_loss: 0.0242 - loss: 0.0853 - val_activity_output_accuracy: 0.6942 - val_activity_output_loss: 2.8849 - val_disease_output_accuracy: 0.4793 - val_disease_output_loss: 1.5202 - val_loss: 3.9282 - val_f1_disease: 0.2160 - val_f1_activity: 0.6275
# Epoch 41/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9844 - activity_output_loss: 0.0538 - disease_output_accuracy: 0.9946 - disease_output_loss: 0.0225 - loss: 0.0791
# Epoch 41: val_loss did not improve from 1.97052
#
# 🔹 Epoch 41 (Fold 18) - Val Macro F1 | Disease: 0.1905 | Activity: 0.6513
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9845 - activity_output_loss: 0.0538 - disease_output_accuracy: 0.9947 - disease_output_loss: 0.0226 - loss: 0.0789 - val_activity_output_accuracy: 0.7240 - val_activity_output_loss: 2.8500 - val_disease_output_accuracy: 0.4000 - val_disease_output_loss: 2.0304 - val_loss: 4.5182 - val_f1_disease: 0.1905 - val_f1_activity: 0.6513
# Epoch 42/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9837 - activity_output_loss: 0.0579 - disease_output_accuracy: 0.9909 - disease_output_loss: 0.0331 - loss: 0.0938
# Epoch 42: val_loss did not improve from 1.97052
#
# 🔹 Epoch 42 (Fold 18) - Val Macro F1 | Disease: 0.1801 | Activity: 0.6218
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9836 - activity_output_loss: 0.0581 - disease_output_accuracy: 0.9908 - disease_output_loss: 0.0329 - loss: 0.0936 - val_activity_output_accuracy: 0.7074 - val_activity_output_loss: 2.8493 - val_disease_output_accuracy: 0.3702 - val_disease_output_loss: 1.9992 - val_loss: 4.6681 - val_f1_disease: 0.1801 - val_f1_activity: 0.6218
# Epoch 43/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9836 - activity_output_loss: 0.0640 - disease_output_accuracy: 0.9908 - disease_output_loss: 0.0296 - loss: 0.0963
# Epoch 43: val_loss did not improve from 1.97052
#
# 🔹 Epoch 43 (Fold 18) - Val Macro F1 | Disease: 0.1916 | Activity: 0.6638
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9836 - activity_output_loss: 0.0638 - disease_output_accuracy: 0.9910 - disease_output_loss: 0.0292 - loss: 0.0960 - val_activity_output_accuracy: 0.7372 - val_activity_output_loss: 2.9039 - val_disease_output_accuracy: 0.4033 - val_disease_output_loss: 2.0622 - val_loss: 4.8166 - val_f1_disease: 0.1916 - val_f1_activity: 0.6638
# Epoch 44/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9867 - activity_output_loss: 0.0509 - disease_output_accuracy: 0.9927 - disease_output_loss: 0.0249 - loss: 0.0786
# Epoch 44: val_loss did not improve from 1.97052
#
# 🔹 Epoch 44 (Fold 18) - Val Macro F1 | Disease: 0.1807 | Activity: 0.6297
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9866 - activity_output_loss: 0.0510 - disease_output_accuracy: 0.9928 - disease_output_loss: 0.0246 - loss: 0.0784 - val_activity_output_accuracy: 0.6975 - val_activity_output_loss: 3.2520 - val_disease_output_accuracy: 0.3719 - val_disease_output_loss: 2.2242 - val_loss: 4.8239 - val_f1_disease: 0.1807 - val_f1_activity: 0.6297
# Epoch 45/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9837 - activity_output_loss: 0.0551 - disease_output_accuracy: 0.9952 - disease_output_loss: 0.0221 - loss: 0.0799
# Epoch 45: val_loss did not improve from 1.97052
#
# 🔹 Epoch 45 (Fold 18) - Val Macro F1 | Disease: 0.1977 | Activity: 0.6388
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - activity_output_accuracy: 0.9837 - activity_output_loss: 0.0549 - disease_output_accuracy: 0.9952 - disease_output_loss: 0.0218 - loss: 0.0796 - val_activity_output_accuracy: 0.7140 - val_activity_output_loss: 2.9850 - val_disease_output_accuracy: 0.4215 - val_disease_output_loss: 2.0633 - val_loss: 4.5307 - val_f1_disease: 0.1977 - val_f1_activity: 0.6388
# Epoch 46/100
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - activity_output_accuracy: 0.9847 - activity_output_loss: 0.0482 - disease_output_accuracy: 0.9981 - disease_output_loss: 0.0141 - loss: 0.0651
# Epoch 46: val_loss did not improve from 1.97052
#
# 🔹 Epoch 46 (Fold 18) - Val Macro F1 | Disease: 0.1933 | Activity: 0.6344
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - activity_output_accuracy: 0.9849 - activity_output_loss: 0.0479 - disease_output_accuracy: 0.9980 - disease_output_loss: 0.0142 - loss: 0.0649 - val_activity_output_accuracy: 0.7124 - val_activity_output_loss: 3.0555 - val_disease_output_accuracy: 0.4083 - val_disease_output_loss: 2.1099 - val_loss: 4.4399 - val_f1_disease: 0.1933 - val_f1_activity: 0.6344
# Epoch 47/100
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - activity_output_accuracy: 0.9884 - activity_output_loss: 0.0434 - disease_output_accuracy: 0.9966 - disease_output_loss: 0.0163 - loss: 0.0625

# %%
import os

fold_path = os.path.join(BASE_CHECKPOINT_DIR, f"fold_{best_fold_no}")
print("Files in best fold checkpoint folder:", os.listdir(fold_path))
# Out:
# Files in best fold checkpoint folder: ['epoch_070_valLoss_3.1338.keras', 'epoch_060_valLoss_2.5718.keras', 'epoch_010_valLoss_1.9092.keras', 'epoch_020_valLoss_2.1781.keras', 'epoch_030_valLoss_2.3062.keras', 'epoch_100_valLoss_3.7675.keras', 'epoch_040_valLoss_2.6745.keras', 'epoch_050_valLoss_2.6760.keras', 'epoch_090_valLoss_3.4309.keras', 'best_model.keras', 'epoch_080_valLoss_3.0655.keras']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import f1_score, accuracy_score

# -----------------------------
# 1️⃣ Fold-level Accuracy Plots
# -----------------------------
# Disease Accuracy
plt.figure(figsize=(10,5))
plt.bar(results_df['fold'], results_df['val_disease_acc'], color='skyblue')
plt.title("Validation Disease Accuracy per Fold")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.show()

# Activity Accuracy
plt.figure(figsize=(10,5))
plt.bar(results_df['fold'], results_df['val_activity_acc'], color='salmon')
plt.title("Validation Activity Accuracy per Fold")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.show()

print(f"Average Disease Accuracy: {results_df.val_disease_acc.mean():.4f}")
print(f"Average Activity Accuracy: {results_df.val_activity_acc.mean():.4f}")

# -----------------------------
# 2️⃣ F1 Score per Fold
# -----------------------------
f1_disease_per_fold = []
f1_activity_per_fold = []

for fold_no, test_subject in enumerate(np.unique(y_subject), 1):
    val_idx = np.where(y_subject == test_subject)[0]
    X_val_fold = X_scaled[val_idx]
    y_val_disease_fold = y_disease[val_idx]
    y_val_activity_fold = y_activity[val_idx]

    fold_model_path = os.path.join(BASE_CHECKPOINT_DIR, f"fold_{fold_no}", "best_model.keras")
    fold_model = tf.keras.models.load_model(fold_model_path)

    y_pred_probs = fold_model.predict(X_val_fold, verbose=0)
    y_pred_disease = np.argmax(y_pred_probs[0], axis=1)  # use index 0
    y_pred_activity = np.argmax(y_pred_probs[1], axis=1)  # use index 1

    f1_disease_per_fold.append(f1_score(y_val_disease_fold, y_pred_disease, average='macro'))
    f1_activity_per_fold.append(f1_score(y_val_activity_fold, y_pred_activity, average='macro'))

# Plot F1 Scores
plt.figure(figsize=(10,5))
plt.bar(range(1, len(f1_disease_per_fold)+1), f1_disease_per_fold, color='lightgreen', alpha=0.7, label='Disease F1')
plt.bar(range(1, len(f1_activity_per_fold)+1), f1_activity_per_fold, color='orange', alpha=0.7, label='Activity F1')
plt.title("Validation F1 Scores per Fold")
plt.xlabel("Fold")
plt.ylabel("Macro F1 Score")
plt.legend()
plt.show()

print(f"Average Disease F1 Score: {np.mean(f1_disease_per_fold):.4f}")
print(f"Average Activity F1 Score: {np.mean(f1_activity_per_fold):.4f}")
# Out:
# Average Disease Accuracy: 0.3275
# Average Activity Accuracy: 0.6195
# Average Disease F1 Score: 0.1879
# Average Activity F1 Score: 0.5383
